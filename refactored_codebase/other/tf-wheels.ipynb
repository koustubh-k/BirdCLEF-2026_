# %%
# Create a directory to store wheels
import os
os.makedirs("/kaggle/working/tf_wheels", exist_ok=True)

# Download TensorFlow 2.20 and TensorBoard 2.20 wheels
# !pip download --no-deps -d /kaggle/working/tf_wheels \
    tensorflow==2.20.0 \
    tensorboard==2.20.0

# Verify files
# !ls -lh /kaggle/working/tf_wheels
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.7/620.7 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 72.4 MB/s eta 0:00:00:00:0100:01
# Saved ./tf_wheels/tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Saved ./tf_wheels/tensorboard-2.20.0-py3-none-any.whl
# Successfully downloaded tensorflow tensorboard
# total 598M
# -rw-r--r-- 1 root root 5.3M Mar 24 09:45 tensorboard-2.20.0-py3-none-any.whl
# -rw-r--r-- 1 root root 592M Mar 24 09:45 tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl

# %%
# !ls /kaggle/working/tf_wheels
# Out:
# tensorboard-2.20.0-py3-none-any.whl
# tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
